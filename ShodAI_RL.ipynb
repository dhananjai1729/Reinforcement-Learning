# %%
import sys
import os
kernel_name = os.path.basename(sys.executable.replace("/bin/python",""))
print(kernel_name)
# Out:
# ShodhAI_1

# %% [markdown]
# ## CPU Scheduling Objectives
#
# After analyzing the problem statement and data, several potential objectives were identified:
#
# 1. **Minimize Total Burst Time**: The goal is to minimize the total time required to complete all processes. This objective is critical for maximizing overall system throughput.
#
# 2. **Minimize Average Waiting Time**: Aimed at reducing the average waiting time for processes in the queue, thereby enhancing system responsiveness and user experience.
#
# 3. **Minimize Average Turnaround Time**: Focuses on minimizing the total time from process arrival to its completion, optimizing process efficiency.
#
# 4. **Maximize Resource Utilization**: Ensures efficient use of available resources to prevent idle time while maintaining other performance metrics.
#
# 5. **Minimize Context Switching**: Reduces the number of context switches between processes, which can lower overhead and improve system performance.
#
# Given the constraints and time limitations, the chosen objective for this project is to **minimize total burst time**.

# %% [markdown]
# # Install necessary libraries

# %%
pip install pandas
pip install gymnasium 
conda install conda-forge::stable-baselines3

# %% [markdown]
# # Import Libraries

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# # Environment Initialization

# %%
class CPUSchedulingEnv(gym.Env):
    def __init__(self):
        super(CPUSchedulingEnv, self).__init__()
        self.action_space = spaces.Discrete(10)
        self.observation_space = spaces.Box(low=0, high=1, shape=(7,), dtype=np.float32)
        self.current_job_index = 0
        self.current_time = 0
        self.completed_jobs = []
        self.job_queue = []
        self.resources_used = 0
        self.data = None
        self.max_burst_time = None
        self.max_resources = None
        self.np_random = None
        self.seed()

    def seed(self, seed=None):
        self.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]

    def _load_data(self):
        data = pd.DataFrame({
            'Job Id': range(500),
            'Burst time': self.np_random.integers(1, 500, size=500),
            'Arrival Time': self.np_random.uniform(0, 1000, size=500),
            'Preemptive': self.np_random.integers(0, 2, size=500),
            'Resources': self.np_random.integers(1, 10, size=500)
        })
        data = data.sort_values(by='Arrival Time').reset_index(drop=True)
        return data

    def _get_observation(self):
        if len(self.job_queue) > 0:
            next_job = self.job_queue[0]
            obs = np.array([
                next_job['Job Id'] / len(self.data),
                next_job['Burst time'] / self.max_burst_time,
                next_job['Arrival Time'] / self.data['Arrival Time'].max(),
                next_job['Preemptive'],
                next_job['Resources'] / self.max_resources,
                self.resources_used / 20,
                self.current_time / self.data['Arrival Time'].max()
            ])
        else:
            obs = np.zeros(7)
        return np.clip(obs, self.observation_space.low, self.observation_space.high)

    def _update_job_queue(self):
        while self.current_job_index < len(self.data) and self.data.iloc[self.current_job_index]["Arrival Time"] <= self.current_time:
            self.job_queue.append(self.data.iloc[self.current_job_index])
            self.current_job_index += 1

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_job_index = 0
        self.current_time = 0
        self.completed_jobs = []
        self.job_queue = []
        self.resources_used = 0
        self.data = self._load_data()
        self.max_burst_time = self.data['Burst time'].max()
        self.max_resources = self.data['Resources'].max()
        self._update_job_queue()
        observation = self._get_observation()
        info = {}  # You can add any relevant reset information here
        return observation, info

    def step(self, action):
        self._update_job_queue()
        if action < len(self.job_queue):
            selected_job = self.job_queue[action]
        else:
            selected_job = None

        reward = 0
        done = False

        if selected_job:
            job_resources = selected_job['Resources']
            if job_resources + self.resources_used <= 20:
                self.resources_used += job_resources
                self.current_time += selected_job['Burst time']
                waiting_time = self.current_time - selected_job['Arrival Time']
                reward = -waiting_time / 1000  # Normalize reward
                self.completed_jobs.append(selected_job)
                self.job_queue.remove(selected_job)
                self.resources_used -= job_resources
            else:
                reward = -0.1  # Small penalty for selecting a job that exceeds resource limits
        else:
            reward = -0.1  # Small penalty for invalid action

        if self.current_job_index >= len(self.data) and len(self.job_queue) == 0:
            done = True
            reward += 10  # Reward for completing all jobs

        observation = self._get_observation()
        info = {}  # You can add any relevant step information here
        return observation, reward, done, False, info  # Added False for truncated

# %% [markdown]
# # Training the model using PPO

# %% [markdown]
# ## Why PPO is a Better Method for CPU Scheduling
#
# PPO (Proximal Policy Optimization) is preferred for CPU scheduling due to its ability to handle continuous action spaces and adapt to dynamic environments through reinforcement learning. Unlike traditional methods relying on static rules, PPO learns optimal scheduling policies directly from environment interactions. This adaptive approach allows PPO to potentially outperform fixed algorithms by continuously refining policies based on received rewards and penalties. As a result, PPO can efficiently manage CPU resource utilization and improve job completion times in dynamic and unpredictable scheduling scenarios.

# %%
# Create and wrap the environment
env = make_vec_env(CPUSchedulingEnv, n_envs=4)
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10., clip_reward=10.)

# Create and train the PPO model
model = PPO("MlpPolicy", env, verbose=1, learning_rate=3e-4, n_steps=2048, batch_size=64, n_epochs=10, gamma=0.99, gae_lambda=0.95, clip_range=0.2, ent_coef=0.01)
model.learn(total_timesteps=500000)

# Save the model
model.save("ppo_cpu_scheduling")

# Test the model
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, infos = env.step(action)
    if dones.any():
        obs = env.reset()
# Out:
# Using cpu device
# ------------------------------
# | time/              |       |
# |    fps             | 10939 |
# |    iterations      | 1     |
# |    time_elapsed    | 0     |
# |    total_timesteps | 8192  |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5301        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013445817 |
# |    clip_fraction        | 0.0369      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 0.287       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4541        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010192031 |
# |    clip_fraction        | 0.000146    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0296     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 0.0358      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4109        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012296065 |
# |    clip_fraction        | 0.0123      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3888        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013681114 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00547    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3775       |
# |    iterations           | 6          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00787685 |
# |    clip_fraction        | 0.00454    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.000669  |
# |    value_loss           | 0.0304     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3722       |
# |    iterations           | 7          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01192786 |
# |    clip_fraction        | 0.0271     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.29      |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0294    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00266   |
# |    value_loss           | 0.0285     |
# ----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 3659     |
# |    iterations           | 8        |
# |    time_elapsed         | 17       |
# |    total_timesteps      | 65536    |
# | train/                  |          |
# |    approx_kl            | 0.011271 |
# |    clip_fraction        | 0.0172   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.29    |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0191  |
# |    n_updates            | 70       |
# |    policy_gradient_loss | -0.00198 |
# |    value_loss           | 0.026    |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3596        |
# |    iterations           | 9           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009494671 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0269     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.0253      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3530        |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011441536 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.029      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 0.0225      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3485         |
# |    iterations           | 11           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0095256325 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00388      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 0.0204       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3448        |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013840449 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 0.0203      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3425         |
# |    iterations           | 13           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0061547332 |
# |    clip_fraction        | 0.00281      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0194      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 0.0178       |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3425       |
# |    iterations           | 14         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.00869045 |
# |    clip_fraction        | 0.0273     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0475    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00224   |
# |    value_loss           | 0.0167     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3430        |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.008647881 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 0.016       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3437        |
# |    iterations           | 16          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010838855 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.008827282 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3431         |
# |    iterations           | 18           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0120764775 |
# |    clip_fraction        | 0.0346       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00362     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 0.0122       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 19          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.010298949 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3422        |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011546357 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00638    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3422        |
# |    iterations           | 21          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.014618509 |
# |    clip_fraction        | 0.0655      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0376     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 0.00951     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3430        |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010251827 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0449     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00074    |
# |    value_loss           | 0.0088      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010287099 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000425   |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 0.0083      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3442        |
# |    iterations           | 24          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011641642 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00348     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 0.0076      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3438        |
# |    iterations           | 25          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.010002948 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00739    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 0.00735     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3446        |
# |    iterations           | 26          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.010865925 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00883     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 0.0067      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3452       |
# |    iterations           | 27         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.01637466 |
# |    clip_fraction        | 0.0624     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.08      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0168    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00471   |
# |    value_loss           | 0.00632    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3453        |
# |    iterations           | 28          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.010705685 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 0.00607     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3457        |
# |    iterations           | 29          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.008054817 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 0.00544     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3457        |
# |    iterations           | 30          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.011711882 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00442    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 0.00535     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3453        |
# |    iterations           | 31          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.014623603 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0103      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 0.00497     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3457        |
# |    iterations           | 32          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.007818356 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 0.00452     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3464        |
# |    iterations           | 33          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.008634938 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000682   |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3469        |
# |    iterations           | 34          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.007468317 |
# |    clip_fraction        | 0.0184      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00853    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000935   |
# |    value_loss           | 0.00422     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3472        |
# |    iterations           | 35          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.014172455 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 0.00403     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3476        |
# |    iterations           | 36          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.011774395 |
# |    clip_fraction        | 0.043       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3465        |
# |    iterations           | 37          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.006766396 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00552    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 0.00374     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3458        |
# |    iterations           | 38          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.012320645 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0273     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.00356     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3455        |
# |    iterations           | 39          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.011849519 |
# |    clip_fraction        | 0.0231      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0215     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 0.0035      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3453        |
# |    iterations           | 40          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.014769571 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 0.00331     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3438        |
# |    iterations           | 41          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.008087451 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0315     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3406        |
# |    iterations           | 42          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.009606196 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0269     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 0.00317     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3371       |
# |    iterations           | 43         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 352256     |
# | train/                  |            |
# |    approx_kl            | 0.01014827 |
# |    clip_fraction        | 0.0234     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0561    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00221   |
# |    value_loss           | 0.00296    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3360         |
# |    iterations           | 44           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0073837223 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0237      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 0.00287      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3342        |
# |    iterations           | 45          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.013489047 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00447    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3335        |
# |    iterations           | 46          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.006769033 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000569   |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3326        |
# |    iterations           | 47          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.009052748 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3327        |
# |    iterations           | 48          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.010653924 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00425    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3322        |
# |    iterations           | 49          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014099771 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0518     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 0.00252     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3323        |
# |    iterations           | 50          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.013516221 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00599     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3308         |
# |    iterations           | 51           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.0096133305 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0159      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3295        |
# |    iterations           | 52          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.008196676 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3275        |
# |    iterations           | 53          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.010465868 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.032      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3276        |
# |    iterations           | 54          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005362571 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.000928   |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3270        |
# |    iterations           | 55          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.008281393 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0315     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3271        |
# |    iterations           | 56          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.007512525 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3272        |
# |    iterations           | 57          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.011944521 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00917    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3274        |
# |    iterations           | 58          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.012168091 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0516     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3276        |
# |    iterations           | 59          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.011860948 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 0.00198     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3274        |
# |    iterations           | 60          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.011741057 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0347     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3268        |
# |    iterations           | 61          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.014155623 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.28       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0465     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3267        |
# |    iterations           | 62          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.009978485 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0503     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 0.00184     |
# -----------------------------------------

# %% [markdown]
# # Resources
# - [Gymnasium](https://gymnasium.farama.org/)
# - [YouTube - Nicholas Renotte's Reinforcement Learning Playlist](https://www.youtube.com/watch?v=Mut_u40Sqz4&list=PLgNJO2hghbmjlE6cuKMws2ejC54BTAaWV&index=8&ab_channel=NicholasRenotte)
# - [YouTube - Nicholas Renotte's Custom Environments Tutorial](https://www.youtube.com/watch?v=bD6V3rcr_54&list=PLgNJO2hghbmjlE6cuKMws2ejC54BTAaWV&index=3&ab_channel=NicholasRenotte)
# - [Creating Custom Environments in OpenAI Gym](https://saashanair.com/blog/blog-posts/custom-environments-in-openai-gym)
# - [ChatGPT](https://chatgpt.com/)
# - [Claude AI](https://claude.ai/chat)

# %% [markdown]
# # Possible additions
# - Add evaluation and testing
# - Create a comparison with normal optimisation methods like Pulp or with current algorithms for CPU scheduling
# - Create a hybrid model
